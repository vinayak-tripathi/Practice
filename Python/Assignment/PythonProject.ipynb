# %%
import pandas as pd
import numpy as np
from openpyxl import load_workbook

# %%
file = load_workbook('PythonProject.xlsx')
file.sheetnames
# Out:
# ['Input', 'Product Details', 'Working', 'Output']

# %%
ip_file = pd.read_excel('PythonProject.xlsx',sheet_name = 'Input',usecols=['Product','Packing Details','QTY'])
product_details = pd.read_excel('PythonProject.xlsx',sheet_name = 'Product Details',usecols = ['Product', 'Packing Details', 'Rate'])

# %%
ip_file['Packing Details'] = ip_file['Packing Details'].fillna(ip_file['Product'].str.extract(r'\(([A-Za-z0-9]+\sx\s\d+[A-Za-z]*)\)')[0])
ip_file['Product'] = ip_file['Product'].str.replace(r'\s\([A-Za-z0-9]+\sx\s\d+[A-Za-z]*\)','',regex = True)
processed = ip_file.set_index(['Product']).combine_first(product_details[['Product','Packing Details']].set_index(['Product'])).reset_index()

# %%
vt = ip_file.merge(product_details,on=['Product'])

# %%
 vt.loc[vt[vt['Packing Details_x'].isna()].index,'Packing Details_x'] = vt.loc[vt[vt['Packing Details_x'].isna()].index,'Packing Details_y']

# %%
vt
# Out:
#                                      Product Packing Details_x  QTY  \
# 0                      Knorr Soup Sweet Corn       50g x 48Pkt   10
# 1                                 Tiger Balm     21ml x 120Pcs    5
# 2                         Knorr Soup Mix Veg       43g x 48Pkt   10
# 3                            Food Color Blue          25g x 96   10
# 4                       Mouth Freshner Zaika     12Btl x 4Tray   18
# 5                           Dabur Janamghuti     60ml x 100Btl   15
# 6                           Dabur Janamghuti     125ml x 48Btl   15
# 7                  Knorr Veg Soup Hot & Sour       43g x 48Pkt   10
# 8                Himalaya Neem Turmeric Soap      125g x 72Pcs    5
# 9              Cinthol Soap - Original (Red)     100g x 160Pcs    5
# 10                         Pudin Hara Tablet  40Strips x 16Box    5
# 11                                Zandu Balm      8ml x 400pcs    5
# 12  Glow & Lovely Advance Multivitamin Cream       80g x 36Box    5
# 13                  Antiseptic Liquid Dettol      1Ltr x 12Btl   50
# 14                  Antiseptic Liquid Dettol      1Ltr x 12Btl   50
# 15                              Navratan Oil     500ml x 24Btl   10
#
#    Packing Details_y        Rate
# 0        50g x 48Pkt   37.509167
# 1      21ml x 120Pcs   64.730000
# 2        43g x 48Pkt   37.509167
# 3           25g x 96   19.662500
# 4      12Btl x 4Tray  670.000000
# 5      60ml x 100Btl   30.744000
# 6      125ml x 48Btl   52.407000
# 7        43g x 48Pkt   37.509167
# 8       125g x 72Pcs   30.220000
# 9      100g x 160Pcs   30.730000
# 10  40Strips x 16Box  621.240000
# 11      8ml x 400pcs   30.180000
# 12       80g x 36Box  122.722222
# 13      1Ltr x 12Btl  227.070000
# 14     550ml x 24Btl  133.310000
# 15     500ml x 24Btl  229.470000

# %%
vt = vt.drop_duplicates(subset=['Product', 'Packing Details_x'], keep='first').rename(columns = {'Packing Details_x':'Packing Details'})[['Product','Packing Details','QTY','Rate']]

# %%
vt.index=range(1,len(vt)+1)

# %%
vt.rename_axis('Sr. No.',axis=0).index
# Out:
# RangeIndex(start=1, stop=16, step=1, name='Sr. No.')

# %%
vt
# Out:
#                                      Product   Packing Details  QTY  \
# 1                      Knorr Soup Sweet Corn       50g x 48Pkt   10
# 2                                 Tiger Balm     21ml x 120Pcs    5
# 3                         Knorr Soup Mix Veg       43g x 48Pkt   10
# 4                            Food Color Blue          25g x 96   10
# 5                       Mouth Freshner Zaika     12Btl x 4Tray   18
# 6                           Dabur Janamghuti     60ml x 100Btl   15
# 7                           Dabur Janamghuti     125ml x 48Btl   15
# 8                  Knorr Veg Soup Hot & Sour       43g x 48Pkt   10
# 9                Himalaya Neem Turmeric Soap      125g x 72Pcs    5
# 10             Cinthol Soap - Original (Red)     100g x 160Pcs    5
# 11                         Pudin Hara Tablet  40Strips x 16Box    5
# 12                                Zandu Balm      8ml x 400pcs    5
# 13  Glow & Lovely Advance Multivitamin Cream       80g x 36Box    5
# 14                  Antiseptic Liquid Dettol      1Ltr x 12Btl   50
# 15                              Navratan Oil     500ml x 24Btl   10
#
#           Rate
# 1    37.509167
# 2    64.730000
# 3    37.509167
# 4    19.662500
# 5   670.000000
# 6    30.744000
# 7    52.407000
# 8    37.509167
# 9    30.220000
# 10   30.730000
# 11  621.240000
# 12   30.180000
# 13  122.722222
# 14  227.070000
# 15  229.470000

# %%
def read_input(file_location:str):
    return pd.read_excel(file_location,sheet_name = 'Input',usecols=['Product','Packing Details','QTY'])
 
def read_productdetails(file_location:str):
    return pd.read_excel('PythonProject.xlsx',sheet_name = 'Product Details',usecols = ['Product', 'Packing Details', 'Rate'])

def preprocess(ip_file,product_details):
    ip_file['Packing Details'] = ip_file['Packing Details'].fillna(ip_file['Product'].str.extract(r'\(([A-Za-z0-9]+\sx\s\d+[A-Za-z]*)\)')[0])
    ip_file['Product'] = ip_file['Product'].str.replace(r'\s\([A-Za-z0-9]+\sx\s\d+[A-Za-z]*\)','',regex = True)
#     processed = ip_file.set_index(['Product']).combine_first(product_details[['Product','Packing Details']].set_index(['Product'])).reset_index()
    vt = ip_file.merge(product_details,on=['Product'])
    vt.loc[vt[vt['Packing Details_x'].isna()].index,'Packing Details_x'] = vt.loc[vt[vt['Packing Details_x'].isna()].index,'Packing Details_y']
    final = vt.drop_duplicates(subset=['Product', 'Packing Details_x'], keep='first')
    final = final.rename(columns = {'Packing Details_x':'Packing Details'})
    return final[['Product','Packing Details','QTY','Rate']]
 
def getUSD_INR_rate():
    import requests
    true = True
    url = "https://api.apilayer.com/fixer/convert?to=INR&from=USD&amount=1"
    payload = {}
    headers= {
      "apikey": "1oqMRDhezrQkPfqIeJhEP91o6AxOCMwR"
    }
    response = requests.request("GET", url, headers=headers, data = payload)
    status_code = response.status_code
    result = response.text
    return eval(result)['info']['rate']

def transform(processed):
    processed['Pieces per Unit'] = processed['Packing Details'].str.extract(r'[A-Za-z0-9]+\sx\s(\d+)[A-Za-z]*').astype('int64')
    dollar_inr_rate = 72
    margin = 0.12
    processed['Rate (USD)'] = processed['Rate']/dollar_inr_rate
    processed['Rate per Package (USD)']=processed['Pieces per Unit']*processed['Rate']*(1+margin)/dollar_inr_rate
    processed['Total Amount (USD)'] = processed['Rate per Package (USD)']*processed['QTY']
    processed.index=processed.index=range(1,len(processed)+1)
    processed.rename_axis('Sr. No.',axis=0,inplace=True)
    return processed[['Product', 'Packing Details', 'QTY','Rate per Package (USD)','Total Amount (USD)']].round(decimals=2)

def transform_currentUSDRate(processed):
    processed['Pieces per Unit'] = processed['Packing Details'].str.extract(r'[A-Za-z0-9]+\sx\s(\d+)[A-Za-z]*').astype('int64')
    dollar_inr_rate = getUSD_INR_rate()
    margin = 0.12
    processed['Rate (USD)'] = processed['Rate']/dollar_inr_rate
    processed['Rate per Package (USD)']=processed['Pieces per Unit']*processed['Rate']*(1+margin)/dollar_inr_rate
    processed['Total Amount (USD)'] = processed['Rate per Package (USD)']*processed['QTY']
    processed.index=processed.index=range(1,len(processed)+1)
    processed.rename_axis('Sr. No.',axis=0,inplace=True)
    return processed[['Product', 'Packing Details', 'QTY','Rate per Package (USD)','Total Amount (USD)']].round(decimals=2)

def etl_prices(file_loc:str):
    ip = read_input(file_loc)
    product_details = read_productdetails(file_loc)
    preprocessed_ip = preprocess(ip,product_details)
#     return transform_currentUSDRate(preprocessed_ip,product_details)
    return transform(preprocessed_ip)

# %%
etl_prices('PythonProject.xlsx')
# Out:
#                                           Product   Packing Details  QTY  \
# Sr. No.
# 1                           Knorr Soup Sweet Corn       50g x 48Pkt   10
# 2                                      Tiger Balm     21ml x 120Pcs    5
# 3                              Knorr Soup Mix Veg       43g x 48Pkt   10
# 4                                 Food Color Blue          25g x 96   10
# 5                            Mouth Freshner Zaika     12Btl x 4Tray   18
# 6                                Dabur Janamghuti     60ml x 100Btl   15
# 7                                Dabur Janamghuti     125ml x 48Btl   15
# 8                       Knorr Veg Soup Hot & Sour       43g x 48Pkt   10
# 9                     Himalaya Neem Turmeric Soap      125g x 72Pcs    5
# 10                  Cinthol Soap - Original (Red)     100g x 160Pcs    5
# 11                              Pudin Hara Tablet  40Strips x 16Box    5
# 12                                     Zandu Balm      8ml x 400pcs    5
# 13       Glow & Lovely Advance Multivitamin Cream       80g x 36Box    5
# 14                       Antiseptic Liquid Dettol      1Ltr x 12Btl   50
# 15                                   Navratan Oil     500ml x 24Btl   10
#
#          Rate per Package (USD)  Total Amount (USD)
# Sr. No.
# 1                         28.01              280.07
# 2                        120.83              604.15
# 3                         28.01              280.07
# 4                         29.36              293.63
# 5                         41.69              750.40
# 6                         47.82              717.36
# 7                         39.13              586.96
# 8                         28.01              280.07
# 9                         33.85              169.23
# 10                        76.48              382.42
# 11                       154.62              773.10
# 12                       187.79              938.93
# 13                        68.72              343.62
# 14                        42.39             2119.32
# 15                        85.67              856.69

# %%
ip = read_input('PythonProject.xlsx')
pr = read_productdetails('PythonProject.xlsx')

# %%
transform(preprocess(ip,pr))
# Out:
#                                      Product   Packing Details  QTY  \
# 0                      Knorr Soup Sweet Corn       50g x 48Pkt   10
# 1                                 Tiger Balm     21ml x 120Pcs    5
# 2                         Knorr Soup Mix Veg       43g x 48Pkt   10
# 3                            Food Color Blue          25g x 96   10
# 4                       Mouth Freshner Zaika     12Btl x 4Tray   18
# 5                           Dabur Janamghuti     60ml x 100Btl   15
# 6                           Dabur Janamghuti     125ml x 48Btl   15
# 7                  Knorr Veg Soup Hot & Sour       43g x 48Pkt   10
# 8                Himalaya Neem Turmeric Soap      125g x 72Pcs    5
# 9              Cinthol Soap - Original (Red)     100g x 160Pcs    5
# 10                         Pudin Hara Tablet  40Strips x 16Box    5
# 11                                Zandu Balm      8ml x 400pcs    5
# 12  Glow & Lovely Advance Multivitamin Cream       80g x 36Box    5
# 13                  Antiseptic Liquid Dettol      1Ltr x 12Btl   50
# 15                              Navratan Oil     500ml x 24Btl   10
#
#     Rate per Package (USD)  Total Amount (USD)
# 0                28.006844          280.068444
# 1               120.829333          604.146667
# 2                28.006844          280.068444
# 3                29.362667          293.626667
# 4                41.688889          750.400000
# 5                47.824000          717.360000
# 6                39.130560          586.958400
# 7                28.006844          280.068444
# 8                33.846400          169.232000
# 9                76.483556          382.417778
# 10              154.619733          773.098667
# 11              187.786667          938.933333
# 12               68.724444          343.622222
# 13               42.386400         2119.320000
# 15               85.668800          856.688000

# %%
pr
# Out:
#                                      Product   Packing Details        Rate
# 0                   Antiseptic Liquid Dettol      1Ltr x 12Btl  227.070000
# 1                   Antiseptic Liquid Dettol     550ml x 24Btl  133.310000
# 2                           Dabur Janamghuti     60ml x 100Btl   30.744000
# 3                           Dabur Janamghuti     125ml x 48Btl   52.407000
# 4                               Navratan Oil     500ml x 24Btl  229.470000
# 5                          Pudin Hara Tablet  40Strips x 16Box  621.240000
# 6                                 Tiger Balm     21ml x 120Pcs   64.730000
# 7                            Food Color Blue          25g x 96   19.662500
# 8                       Mouth Freshner Zaika     12Btl x 4Tray  670.000000
# 9                  Knorr Veg Soup Hot & Sour       43g x 48Pkt   37.509167
# 10                        Knorr Soup Mix Veg       43g x 48Pkt   37.509167
# 11                     Knorr Soup Sweet Corn       50g x 48Pkt   37.509167
# 12               Himalaya Neem Turmeric Soap      125g x 72Pcs   30.220000
# 13  Glow & Lovely Advance Multivitamin Cream       80g x 36Box  122.722222
# 14             Cinthol Soap - Original (Red)     100g x 160Pcs   30.730000
# 15                                Zandu Balm      8ml x 400pcs   30.180000

# %%
def transform(processed,product_details):
    '''ip_file --> unprocessed dataframe
    product_details --> product details dataframe
    This function transforms the processed dataframe and returns the tranformed final output dataframe
    '''
    processed['Pieces per Unit'] = processed['Packing Details'].str.extract(r'[A-Za-z0-9]+\sx\s(\d+)[A-Za-z]*').astype('int64')
    merged = processed.merge(product_details,on = ['Product','Packing Details'])
    dollar_inr_rate = 72
    margin = 0.12
    merged['Rate (USD)'] = merged['Rate']/dollar_inr_rate
    merged['Rate per Package (USD)']=merged['Pieces per Unit']*merged['Rate']*(1+margin)/dollar_inr_rate
    merged['Total Amount (USD)'] = merged['Rate per Package (USD)']*merged['QTY']
    return merged[['Product', 'Packing Details', 'QTY','Rate per Package (USD)','Total Amount (USD)']]

# %%
vt
# Out:
#                                      Product   Packing Details  QTY  \
# 0                      Knorr Soup Sweet Corn       50g x 48Pkt   10
# 1                                 Tiger Balm     21ml x 120Pcs    5
# 2                         Knorr Soup Mix Veg       43g x 48Pkt   10
# 3                            Food Color Blue          25g x 96   10
# 4                       Mouth Freshner Zaika     12Btl x 4Tray   18
# 5                           Dabur Janamghuti     60ml x 100Btl   15
# 6                           Dabur Janamghuti     125ml x 48Btl   15
# 7                  Knorr Veg Soup Hot & Sour       43g x 48Pkt   10
# 8                Himalaya Neem Turmeric Soap      125g x 72Pcs    5
# 9              Cinthol Soap - Original (Red)     100g x 160Pcs    5
# 10                         Pudin Hara Tablet  40Strips x 16Box    5
# 11                                Zandu Balm      8ml x 400pcs    5
# 12  Glow & Lovely Advance Multivitamin Cream       80g x 36Box    5
# 13                  Antiseptic Liquid Dettol      1Ltr x 12Btl   50
# 15                              Navratan Oil     500ml x 24Btl   10
#
#           Rate  Pieces per Unit
# 0    37.509167               48
# 1    64.730000              120
# 2    37.509167               48
# 3    19.662500               96
# 4   670.000000                4
# 5    30.744000              100
# 6    52.407000               48
# 7    37.509167               48
# 8    30.220000               72
# 9    30.730000              160
# 10  621.240000               16
# 11   30.180000              400
# 12  122.722222               36
# 13  227.070000               12
# 15  229.470000               24
